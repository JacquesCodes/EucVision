# %%
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf

# %%
#adopted from:
#https://github.com/csbanon/mnist-classifiers/blob/main/mnist-digits/mnist-digit-classification-with-a-fully-connected-neural-network.ipynb

# %%
# Load the MNIST dataset.
mnist = tf.keras.datasets.mnist
train_data, test_data = mnist.load_data()

# %%
#train_data[0][0]
#train_data[1][0]

# %%
# Divide the data into features and labels.
train_images, train_labels = train_data
test_images, test_labels = test_data

# %%
# Reshape and normalize the images.
X_train = train_images.reshape((60000, 784))
X_train = X_train.astype('float32') / 255
X_test = test_images.reshape((10000, 784))
X_test = X_test.astype('float32') / 255

# %%
# Reshape the labels and encode them categorically.
y_train = tf.keras.utils.to_categorical(train_labels)
y_test = tf.keras.utils.to_categorical(test_labels)

# %%
# Show the shapes of the data.
print("Training Images:", X_train.shape)
print("Testing Images:", X_test.shape)
print("Training Labels:", y_train.shape)
print("Test Labels:", y_test.shape)
# Out:
# Training Images: (60000, 784)
# Testing Images: (10000, 784)
# Training Labels: (60000, 10)
# Test Labels: (10000, 10)

# %%
# Show a sample MNIST digit.
plt.imshow(train_images[4000], cmap=plt.get_cmap('gray'))
plt.show()

# %%
#we can do it better;)
for i in range(9): 
    plt.subplot(330 + 1 + i)
    plt.imshow(train_images[i], cmap=plt.get_cmap('gray'))
plt.show()

# %%
# Define the sequential model.
model = tf.keras.models.Sequential()

# %%
# Add two fully-connected layers to the network.
model.add(tf.keras.layers.Dense(512, activation='relu', input_shape=(28 * 28,)))
model.add(tf.keras.layers.Dense(10, activation='softmax'))
# Out:
# /opt/anaconda3/envs/CHPCSchool/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Show the model.
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 512)            │       401,920 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         5,130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 407,050 (1.55 MB)
#  Trainable params: 407,050 (1.55 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the model.
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Define the parameters.
num_epochs = 10
batch_size = 256

# Train the model.
history = model.fit(X_train, 
                      y_train, 
                      epochs=num_epochs, 
                      batch_size=batch_size, 
                      validation_data=(X_test, y_test))
# Out:
# Epoch 1/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9071 - loss: 0.3311 - val_accuracy: 0.9528 - val_loss: 0.1620
# Epoch 2/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9608 - loss: 0.1384 - val_accuracy: 0.9669 - val_loss: 0.1113
# Epoch 3/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9736 - loss: 0.0912 - val_accuracy: 0.9745 - val_loss: 0.0846
# Epoch 4/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9805 - loss: 0.0677 - val_accuracy: 0.9761 - val_loss: 0.0783
# Epoch 5/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9855 - loss: 0.0511 - val_accuracy: 0.9775 - val_loss: 0.0713
# Epoch 6/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9890 - loss: 0.0396 - val_accuracy: 0.9792 - val_loss: 0.0657
# Epoch 7/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9923 - loss: 0.0300 - val_accuracy: 0.9802 - val_loss: 0.0629
# Epoch 8/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9940 - loss: 0.0240 - val_accuracy: 0.9818 - val_loss: 0.0576
# Epoch 9/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9958 - loss: 0.0185 - val_accuracy: 0.9796 - val_loss: 0.0673
# Epoch 10/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9970 - loss: 0.0146 - val_accuracy: 0.9805 - val_loss: 0.0615

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print('Test Accuracy:', test_accuracy)
print('Test Loss:', test_loss)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 546us/step - accuracy: 0.9805 - loss: 0.0615
# Test Accuracy: 0.9804999828338623
# Test Loss: 0.061460163444280624

# %%
# Save the metrics.
metrics = history.history

# %%
# Save the loss values.
training_loss_list = metrics['loss']
test_loss_list = metrics['val_loss']

# %%
# Plot the training and test loss.
x = np.arange(0, num_epochs, 1)
plt.title('Training and Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.plot(x, training_loss_list, label='Training Loss')
plt.plot(x, test_loss_list, label='Test Loss')
plt.legend()
plt.show()

# %%
train_accuracy_list = metrics['accuracy']
test_accuracy_list = metrics['val_accuracy']

# %%
plt.title('Training and Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.plot(x, train_accuracy_list, label='Training Accuracy')
plt.plot(x, test_accuracy_list, label='Test Accuracy')
plt.legend()
plt.show()

# %%
# Make predictions with the trained model.
predictions = model.predict(X_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 459us/step

# %%
# Choose an index.
index = 900

# Show an image from the test set.
plt.imshow(test_images[index], cmap=plt.get_cmap('gray'))
plt.show()

# %%
print("Prediction:", np.argmax(predictions[index]))
# Out:
# Prediction: 1
